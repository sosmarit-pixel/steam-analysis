# %%
import pandas as pd

input_file = 'reviews_BlackOps7_first1000.csv'
df = pd.read_csv(input_file)
print(f"Loaded {len(df)} reviews from {input_file}")
# Out:
# Loaded 999 reviews from reviews_BlackOps7_first1000.csv

# %%
# Remove duplicate rows
before = len(df)
df = df.drop_duplicates()
print(f"Removed {before - len(df)} duplicates. {len(df)} rows remaining.")
display(df.head())
# Out:
# Removed 786 duplicates. 213 rows remaining.
#                                               review  author_vote  \
# 0  This game is the worst call of duty I have eve...            0
# 1  1/10 - Absolute Trash, AI Slop from Activision...            0
# 2  Game forces you to have Secure Boot and TPM 2....            0
# 3  I was playing Battlefield 6, and after a few b...            0
# 4  Black Ops 7 is a reskin of Black Ops 6 with mo...            0
#
#    other_votes  weighted_vote_score review_date
# 0         1724             0.974877  2026-03-01
# 1         1159             0.932631  2026-03-03
# 2          558             0.927817  2026-05-08
# 3          481             0.909235  2026-03-21
# 4          282             0.870369  2026-05-08

# %%
from textblob import TextBlob


# --------------------------
# Sentiment Analysis
# --------------------------

def get_sentiment(text):

    polarity = TextBlob(text).sentiment.polarity
    return polarity 

    '''
    if polarity > 0.1:
        return "Positive"

    elif polarity < -0.1:
        return "Negative"

    return "Neutral"
    '''

# %%
# --------------------------
# Categorization
# --------------------------
def categorize_review(review):

    usability_keywords = [
        "bug",
        "crash",
        "lag",
        "fps",
        "server",
        "performance",

        "glitch",
        "stutter",
        "freeze",
        "disconnect",
        "error",
        "broken",
        "unoptimized",
        "latency",
        "ping",
        "hitbox",
        "connection",
        "frame rate",
        "loading",
        "memory leak",
    ]

    mechanic_keywords = [
        "movement",
        "weapon",
        "perk",
        "battle pass",
        "matchmaking",

        "loadout",
        "killstreak",
        "scorestreak",
        "operator",
        "map",
        "game mode",
        "respawn",
        "spawn",
        "ability",
        "class",
        "gunplay",
        "ttk",
        "time to kill",
        "recoil",
        "aim assist",
        "multiplayer",
        "zombies",
        "campaign",
        "season",
    ]

    comparison_keywords = [
        "better than",
        "worse than",
        "compared to",
        "similar to",
        
        "just like",
        "same as",
        "feels like",
        "plays like",
        "reminds me of",
        "prefer",
        "used to",
        "previous",
        "original",
        "back in",
        "inferior to",
        "superior to",
        "rip off",
        "copy of",
        "old cod",
    ]

    # New categories based on look for categories AI analysis of full review file
    ai_content_keywords = [
        "slop",
        "ai generated",
        "ai slop",
        "no effort",
        "copy paste",
        "lazy",
        "generated content",
        "soulless",
        "cash grab",
    ]

    monetization_keywords = [
        "refund",
        "worth",
        "price",
        "sale",
        "buying",
        "paid",
        "microtransaction",
        "endgame",
        "season pass",
        "overpriced",
        "free to play",
        "cosmetic",
        "store",
        "bundle",
    ]

    story_keywords = [
        "campaign",
        "story",
        "single player",
        "solo",
        "narrative",
        "mission",
        "ending",
        "cutscene",
        "plot",
        "character",
    ]

    technical_requirements_keywords = [
        "secure boot",
        "tpm",
        "bios",
        "hardware",
        "anti-cheat",
        "ricochet",
        "kernel",
        "driver",
        "compatibility",
        "system requirement",
    ]

    sbmm_keywords = [
        "sbmm",
        "skill based",
        "lobbies",
        "lobby",
        "sweaty",
        "ranked",
        "casual",
        "matchmaking",
        "skill gap",
        "pub stomp",
    ]

    community_keywords = [
        "friends",
        "team",
        "squad",
        "banned",
        "toxic",
        "solo",
        "party",
        "coop",
        "co-op",
        "community",
        "chat",
        "voice",
        "grief",
    ]

    review_lower = review.lower()

    categories = []

    if any(word in review_lower for word in usability_keywords):
        categories.append("Usability Issues")

    if any(word in review_lower for word in mechanic_keywords):
        categories.append("New Mechanic Reception")

    if any(word in review_lower for word in comparison_keywords):
        categories.append("Competitive Analysis")

    if any(word in review_lower for word in ai_content_keywords):
        categories.append("AI-Generated Content Complaints")

    if any(word in review_lower for word in monetization_keywords):
        categories.append("Monetization & Value")

    if any(word in review_lower for word in story_keywords):
        categories.append("Story / Campaign")

    if any(word in review_lower for word in technical_requirements_keywords):
        categories.append("Technical Requirements")

    if any(word in review_lower for word in sbmm_keywords):
        categories.append("SBMM / Matchmaking Frustration")

    if any(word in review_lower for word in community_keywords):
        categories.append("Community & Social")

    if len(categories) == 0:
        categories.append("Game Reception")

    return categories

# %%
# Run sentiment analysis and categorization, then save to a new CSV
sentiments = []
categories = []

for r in df['review']:
    sentiments.append(get_sentiment(r))
    categories.append(', '.join(categorize_review(r)))

df['sentiment'] = sentiments
df['categories'] = categories

display(df)
# Out:
#                                                 review  author_vote  \
# 0    This game is the worst call of duty I have eve...            0
# 1    1/10 - Absolute Trash, AI Slop from Activision...            0
# 2    Game forces you to have Secure Boot and TPM 2....            0
# 3    I was playing Battlefield 6, and after a few b...            0
# 4    Black Ops 7 is a reskin of Black Ops 6 with mo...            0
# ..                                                 ...          ...
# 221  bought this game thinking was gon have fun. no...            0
# 222  UPDATE: Im now at 63 hours played. Zombies is ...            0
# 224  Start game > update requires restart > start g...            0
# 225  Multiplayer : Still no ban for the zen chronus...            0
# 226  This BO7 campaign is the worst thing to happen...            0
#
#      other_votes  weighted_vote_score review_date  sentiment  \
# 0           1724             0.974877  2026-03-01  -0.200000
# 1           1159             0.932631  2026-03-03  -0.096655
# 2            558             0.927817  2026-05-08  -0.071769
# 3            481             0.909235  2026-03-21  -0.055720
# 4            282             0.870369  2026-05-08  -0.002778
# ..           ...                  ...         ...        ...
# 221           39             0.687997  2026-02-12   0.150000
# 222           62             0.687826  2025-11-14  -0.007823
# 224           51             0.685999  2025-12-18  -0.285714
# 225           54             0.684135  2025-11-23  -0.095222
# 226           52             0.733382  2025-12-26   0.071250
#
#                                             categories
# 0                                 Monetization & Value
# 1    Usability Issues, New Mechanic Reception, Comp...
# 2    New Mechanic Reception, Monetization & Value, ...
# 3    Usability Issues, New Mechanic Reception, Comp...
# 4    New Mechanic Reception, AI-Generated Content C...
# ..                                                 ...
# 221                               Monetization & Value
# 222  New Mechanic Reception, Competitive Analysis, ...
# 224  New Mechanic Reception, Monetization & Value, ...
# 225  Usability Issues, New Mechanic Reception, Comp...
# 226           New Mechanic Reception, Story / Campaign
#
# [213 rows x 7 columns]

# %%
# Add a boolean column for each possible category
all_categories = [
    "Usability Issues",
    "New Mechanic Reception",
    "Competitive Analysis",
    "AI-Generated Content Complaints",
    "Monetization & Value",
    "Story / Campaign",
    "Technical Requirements",
    "SBMM / Matchmaking Frustration",
    "Community & Social",
    "Game Reception",
]

for category in all_categories:
    col_name = category.replace(" ", "_").replace("/", "_").replace("&", "and").replace("-", "_")
    col_values = []
    for cat_list in df['categories']:
        col_values.append(category in cat_list)
    df[col_name] = col_values

display(df.head(20))
# Out:
#                                                review  author_vote  \
# 0   This game is the worst call of duty I have eve...            0
# 1   1/10 - Absolute Trash, AI Slop from Activision...            0
# 2   Game forces you to have Secure Boot and TPM 2....            0
# 3   I was playing Battlefield 6, and after a few b...            0
# 4   Black Ops 7 is a reskin of Black Ops 6 with mo...            0
# 5   For the zombies enjoyers out there. Always onl...            0
# 6   AI generated SLOP. No effort, almost everythin...            0
# 7   game is terrible that is all i have to say. li...            0
# 8   Open playlist has reduced SBMM? Where? Why do ...            0
# 9   This game has become a joke. Activision does n...            0
# 10  ABSOLUTELY NEGATIVE, After 6 months of playing...            0
# 11  absolute trash. gave the game a chance at rele...            0
# 12  Biggest pos company on the planet. Bought it. ...            0
# 13  Comm banned for two weeks because someone was ...            0
# 14  Same old formulaic gameplay, labelled as a new...            0
# 15  I loaded up the game, I instantly got, Your PC...            0
# 16  For a game developed by a Triple A studio, you...            0
# 17  This might actually be the worst game I have e...            0
# 18  I grew up playing Call of Duty. My hours on th...            0
# 19  cant play basically any multiplayer because i ...            0
#
#     other_votes  weighted_vote_score review_date  sentiment  \
# 0          1724             0.974877  2026-03-01  -0.200000
# 1          1159             0.932631  2026-03-03  -0.096655
# 2           558             0.927817  2026-05-08  -0.071769
# 3           481             0.909235  2026-03-21  -0.055720
# 4           282             0.870369  2026-05-08  -0.002778
# 5           166             0.818673  2026-03-16  -0.067500
# 6           230             0.813288  2026-03-01  -0.140000
# 7           156             0.795581  2026-05-08  -0.433333
# 8           245             0.856749  2026-04-19  -0.002679
# 9            50             0.745440  2026-05-13  -0.038333
# 10           47             0.737829  2026-06-11  -0.083333
# 11           96             0.719371  2026-03-02  -0.218929
# 12           47             0.690686  2026-04-05  -0.048148
# 13          133             0.737038  2026-05-07  -0.200000
# 14           58             0.682332  2026-03-23  -0.020698
# 15           27             0.682198  2026-05-17  -0.142857
# 16           20             0.672290  2026-05-18  -0.188218
# 17           36             0.667723  2026-05-10  -0.225000
# 18           28             0.667404  2026-03-20  -0.070408
# 19           23             0.643716  2026-06-12   0.256250
#
#                                            categories  Usability_Issues  \
# 0                                Monetization & Value             False
# 1   Usability Issues, New Mechanic Reception, Comp...              True
# 2   New Mechanic Reception, Monetization & Value, ...             False
# 3   Usability Issues, New Mechanic Reception, Comp...              True
# 4   New Mechanic Reception, AI-Generated Content C...             False
# 5   Usability Issues, New Mechanic Reception, Stor...              True
# 6   New Mechanic Reception, AI-Generated Content C...             False
# 7                Story / Campaign, Community & Social             False
# 8   Usability Issues, New Mechanic Reception, Stor...              True
# 9            Monetization & Value, Community & Social             False
# 10                             New Mechanic Reception             False
# 11         Competitive Analysis, Monetization & Value             False
# 12             Usability Issues, Monetization & Value              True
# 13                                 Community & Social             False
# 14                                     Game Reception             False
# 15       New Mechanic Reception, Monetization & Value             False
# 16  Usability Issues, New Mechanic Reception, Comp...              True
# 17                               Monetization & Value             False
# 18                               Competitive Analysis             False
# 19     New Mechanic Reception, Technical Requirements             False
#
#     New_Mechanic_Reception  Competitive_Analysis  \
# 0                    False                 False
# 1                     True                  True
# 2                     True                 False
# 3                     True                  True
# 4                     True                 False
# 5                     True                 False
# 6                     True                 False
# 7                    False                 False
# 8                     True                 False
# 9                    False                 False
# 10                    True                 False
# 11                   False                  True
# 12                   False                 False
# 13                   False                 False
# 14                   False                 False
# 15                    True                 False
# 16                    True                  True
# 17                   False                 False
# 18                   False                  True
# 19                    True                 False
#
#     AI_Generated_Content_Complaints  Monetization_and_Value  Story___Campaign  \
# 0                             False                    True             False
# 1                              True                    True              True
# 2                             False                    True              True
# 3                             False                    True             False
# 4                              True                    True             False
# 5                             False                   False              True
# 6                              True                   False              True
# 7                             False                   False              True
# 8                             False                   False              True
# 9                             False                    True             False
# 10                            False                   False             False
# 11                            False                    True             False
# 12                            False                    True             False
# 13                            False                   False             False
# 14                            False                   False             False
# 15                            False                    True             False
# 16                             True                   False             False
# 17                            False                    True             False
# 18                            False                   False             False
# 19                            False                   False             False
#
#     Technical_Requirements  SBMM___Matchmaking_Frustration  \
# 0                    False                           False
# 1                    False                            True
# 2                     True                           False
# 3                    False                           False
# 4                    False                           False
# 5                    False                           False
# 6                    False                           False
# 7                    False                           False
# 8                    False                            True
# 9                    False                           False
# 10                   False                           False
# 11                   False                           False
# 12                   False                           False
# 13                   False                           False
# 14                   False                           False
# 15                   False                           False
# 16                   False                           False
# 17                   False                           False
# 18                   False                           False
# 19                    True                           False
#
#     Community_and_Social  Game_Reception
# 0                  False           False
# 1                   True           False
# 2                   True           False
# 3                  False           False
# 4                  False           False
# 5                   True           False
# 6                   True           False
# 7                   True           False
# 8                  False           False
# 9                   True           False
# 10                 False           False
# 11                 False           False
# 12                 False           False
# 13                  True           False
# 14                 False            True
# 15                 False           False
# 16                  True           False
# 17                 False           False
# 18                 False           False
# 19                 False           False

# %%
analyzed_file = input_file.replace('.csv', '_analyzed.csv')

df.to_csv(analyzed_file, index=False)
print(f"Saved {len(df)} analyzed reviews to {analyzed_file}")
df[['review', 'sentiment', 'categories']].head()
# Out:
# Saved 213 analyzed reviews to reviews_BlackOps7_first1000_analyzed.csv
#                                               review  sentiment  \
# 0  This game is the worst call of duty I have eve...  -0.200000
# 1  1/10 - Absolute Trash, AI Slop from Activision...  -0.096655
# 2  Game forces you to have Secure Boot and TPM 2....  -0.071769
# 3  I was playing Battlefield 6, and after a few b...  -0.055720
# 4  Black Ops 7 is a reskin of Black Ops 6 with mo...  -0.002778
#
#                                           categories
# 0                               Monetization & Value
# 1  Usability Issues, New Mechanic Reception, Comp...
# 2  New Mechanic Reception, Monetization & Value, ...
# 3  Usability Issues, New Mechanic Reception, Comp...
# 4  New Mechanic Reception, AI-Generated Content C...

# %%
# Read the analyzed CSV back and convert categories from string to list
df_analyzed = pd.read_csv(analyzed_file)

# Convert the categories column from comma-separated string to list
categories_list = []
for cat_string in df_analyzed['categories']:
    cat_list = []
    for cat in cat_string.split(','):
        cat_list.append(cat.strip())
    categories_list.append(cat_list)

df_analyzed['categories'] = categories_list

print(f"Loaded {len(df_analyzed)} analyzed reviews")
print("\nFirst few rows with categories as lists:")
display(df_analyzed)
# Out:
# Loaded 213 analyzed reviews
#
# First few rows with categories as lists:
#                                                 review  author_vote  \
# 0    This game is the worst call of duty I have eve...            0
# 1    1/10 - Absolute Trash, AI Slop from Activision...            0
# 2    Game forces you to have Secure Boot and TPM 2....            0
# 3    I was playing Battlefield 6, and after a few b...            0
# 4    Black Ops 7 is a reskin of Black Ops 6 with mo...            0
# ..                                                 ...          ...
# 208  bought this game thinking was gon have fun. no...            0
# 209  UPDATE: Im now at 63 hours played. Zombies is ...            0
# 210  Start game > update requires restart > start g...            0
# 211  Multiplayer : Still no ban for the zen chronus...            0
# 212  This BO7 campaign is the worst thing to happen...            0
#
#      other_votes  weighted_vote_score review_date  sentiment  \
# 0           1724             0.974877  2026-03-01  -0.200000
# 1           1159             0.932631  2026-03-03  -0.096655
# 2            558             0.927817  2026-05-08  -0.071769
# 3            481             0.909235  2026-03-21  -0.055720
# 4            282             0.870369  2026-05-08  -0.002778
# ..           ...                  ...         ...        ...
# 208           39             0.687997  2026-02-12   0.150000
# 209           62             0.687826  2025-11-14  -0.007823
# 210           51             0.685999  2025-12-18  -0.285714
# 211           54             0.684135  2025-11-23  -0.095222
# 212           52             0.733382  2025-12-26   0.071250
#
#                                             categories  Usability_Issues  \
# 0                               [Monetization & Value]             False
# 1    [Usability Issues, New Mechanic Reception, Com...              True
# 2    [New Mechanic Reception, Monetization & Value,...             False
# 3    [Usability Issues, New Mechanic Reception, Com...              True
# 4    [New Mechanic Reception, AI-Generated Content ...             False
# ..                                                 ...               ...
# 208                             [Monetization & Value]             False
# 209  [New Mechanic Reception, Competitive Analysis,...             False
# 210  [New Mechanic Reception, Monetization & Value,...             False
# 211  [Usability Issues, New Mechanic Reception, Com...              True
# 212         [New Mechanic Reception, Story / Campaign]             False
#
#      New_Mechanic_Reception  Competitive_Analysis  \
# 0                     False                 False
# 1                      True                  True
# 2                      True                 False
# 3                      True                  True
# 4                      True                 False
# ..                      ...                   ...
# 208                   False                 False
# 209                    True                  True
# 210                    True                 False
# 211                    True                  True
# 212                    True                 False
#
#      AI_Generated_Content_Complaints  Monetization_and_Value  \
# 0                              False                    True
# 1                               True                    True
# 2                              False                    True
# 3                              False                    True
# 4                               True                    True
# ..                               ...                     ...
# 208                            False                    True
# 209                            False                    True
# 210                            False                    True
# 211                            False                    True
# 212                            False                   False
#
#      Story___Campaign  Technical_Requirements  SBMM___Matchmaking_Frustration  \
# 0               False                   False                           False
# 1                True                   False                            True
# 2                True                    True                           False
# 3               False                   False                           False
# 4               False                   False                           False
# ..                ...                     ...                             ...
# 208             False                   False                           False
# 209              True                   False                           False
# 210              True                   False                            True
# 211              True                   False                           False
# 212              True                   False                           False
#
#      Community_and_Social  Game_Reception
# 0                   False           False
# 1                    True           False
# 2                    True           False
# 3                   False           False
# 4                   False           False
# ..                    ...             ...
# 208                 False           False
# 209                  True           False
# 210                 False           False
# 211                  True           False
# 212                 False           False
#
# [213 rows x 17 columns]

# %%
# Analysis suggestions:
# What is the number of each of the categories used? (what is the most/least common category)
